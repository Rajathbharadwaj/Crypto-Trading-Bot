# %%
import MetaTrader5 as mt5
from datetime import datetime
import time

# %%
mt5.initialize(
        path="C:\\Program Files\\MetaTrader 5\\terminal64.exe",  # Add this line with your MT5 path
        login=190111246,        # Verify this is your actual account number
        password="QAZwsx456!",  # Verify this is your actual password
        server="Exness-MT5Trial14"  # Verify this is your actual server
    )
mt5.last_error()
# Out:
# (1, 'Success')

# %%
import talib
print(len(talib.get_functions()))
# Out:
# 158

# %%
ticks = mt5.symbol_info_tick("XAUUSD")

# %%
ticks
# Out:
# Tick(time=1732770997, bid=2632.566, ask=2632.678, last=0.0, volume=0, time_msc=1732770997439, flags=6, volume_real=0.0)

# %%
mt5.account_info()
# Out:
# AccountInfo(login=190111246, trade_mode=0, leverage=100, limit_orders=1024, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=966.08, credit=0.0, profit=-66.05, equity=900.03, margin=263.91, margin_free=636.12, margin_level=341.0367170626349, margin_so_call=30.0, margin_so_so=0.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='demo practice', server='Exness-MT5Trial14', currency='USD', company='Exness Technologies Ltd')

# %%
mt5.symbol_info("XAUUSD")
# Out:
# SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1732771001, digits=3, spread=112, spread_float=True, ticks_bookdepth=0, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=1, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=2632.532, bidhigh=2638.456, bidlow=2620.868, ask=2632.644, askhigh=2638.568, asklow=2620.98, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.1, trade_tick_value_profit=0.1, trade_tick_value_loss=0.1, trade_tick_size=0.001, trade_contract_size=100.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, vo
# ...

# %%
mt5.TIMEFRAME_M5
# Out:
# 5

# %%
from trading_bot import GoldTradingBot
from rich.console import Console

# %%
console = Console()

bot = GoldTradingBot()
# Out:
# 🤖 Gold Trading Bot Initializing...
# ╭───────────────────────────────────────────────── Configuration ─────────────────────────────────────────────────╮
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓                                                                 │
# │ ┃ Parameter             ┃               Value ┃                                                                 │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩                                                                 │
# │ │ Symbol                │              XAUUSD │                                                                 │
# │ │ Timeframe             │                  M5 │                                                                 │
# │ │ Volatility Threshold  │                 0.5 │                                                                 │
# │ │ Max SL (pips)         │                  30 │                                                                 │
# ...

# %%
df = bot.get_rates_df()
# Out:
# Fetching market data...
# Rates
# : [(1732283700, 2693.738, 2694.554, 2692.679, 2692.981,  982, 111, 0)
#  (1732284000, 2692.939, 2693.753, 2691.248, 2691.985, 1287, 111, 0)
#  (1732284300, 2691.981, 2692.254, 2689.527, 2691.687, 1271, 111, 0)
#  (1732284600, 2691.743, 2692.753, 2689.505, 2689.814, 1304, 112, 0)
#  (1732284900, 2689.787, 2691.451, 2689.104, 2691.222, 1173, 111, 0)
#  (1732285200, 2691.128, 2692.668, 2688.937, 2689.959, 1240, 112, 0)
#  (1732285500, 2689.924, 2690.055, 2685.897, 2687.724, 1382, 112, 0)
#  (1732285800, 2687.712, 2688.561, 2684.428, 2688.199, 2412, 111, 0)
#  (1732286100, 2688.227, 2691.519, 2686.952, 2691.268, 1724, 111, 0)
#  (1732286400, 2691.226, 2693.513, 2690.463, 2692.97 , 1424, 111, 0)
#  (1732286700, 2692.934, 2693.587, 2688.476, 2692.076, 3140, 111, 0)
#  (1732287000, 2692.1  , 2695.207, 2691.403, 2693.5  , 2290, 111, 0)
#  (1732287300, 2693.536, 2696.358, 2693.36 , 2694.796, 1402, 112, 0)
# ...

# %%
bot.get_rates_df()
# Out:
# Fetching market data...
# Fetched 1000 candles of historical data
# Date range: 2024-11-19 07:40:00 to 2024-11-22 21:55:00
# Latest Market Data:
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┓
# ┃ Time                ┃    Open ┃    High ┃     Low ┃   Close ┃ Volume ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━┩
# │ 2024-11-22 21:35:00 │ 2709.35 │ 2711.56 │ 2708.50 │ 2711.01 │    663 │
# │ 2024-11-22 21:40:00 │ 2711.01 │ 2712.07 │ 2710.69 │ 2711.96 │    407 │
# │ 2024-11-22 21:45:00 │ 2712.00 │ 2712.90 │ 2711.54 │ 2712.74 │    566 │
# │ 2024-11-22 21:50:00 │ 2712.70 │ 2715.33 │ 2712.31 │ 2714.56 │    570 │
# │ 2024-11-22 21:55:00 │ 2714.49 │ 2715.68 │ 2714.23 │ 2715.60 │    539 │
# └─────────────────────┴─────────┴─────────┴─────────┴─────────┴────────┘
#                    time      open      high       low     close  tick_volume  \
# 0   2024-11-19 07:40:00  2620.770  2620.992  2620.015  2620.532          543
# ...

# %%
bot.calculate_supertrend(df)
# Out:
# Calculating Supertrend...
# Supertrend
# :      SUPERT_10_3.0  SUPERTd_10_3.0  SUPERTl_10_3.0  SUPERTs_10_3.0
# 0         0.000000               1             NaN             NaN
# 1              NaN               1             NaN             NaN
# 2              NaN               1             NaN             NaN
# 3              NaN               1             NaN             NaN
# 4              NaN               1             NaN             NaN
# ..             ...             ...             ...             ...
# 995    2629.394407               1     2629.394407             NaN
# 996    2629.394407               1     2629.394407             NaN
# 997    2629.394407               1     2629.394407             NaN
# 998    2629.394407               1     2629.394407             NaN
# 999    2629.394407               1     2629.394407             NaN
#
# [1000 rows x 4 columns]
# Calculated Supertrend using 1000 candles
# Supertrend Calculation Results:
# ...

# %%
bot.calculate_volatility(df)
# Out:
# Calculating Volatility Switch...
# Calculated Volatility using 1000 candles
# Volatility Calculation Results:
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Time                ┃ ATR     ┃ Volatility Switch ┃ Status      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ 2024-11-28 04:55:00 │ 1.45582 │ 0.00055           │ ❌ INACTIVE │
# │ 2024-11-28 05:00:00 │ 1.44176 │ 0.00055           │ ❌ INACTIVE │
# │ 2024-11-28 05:05:00 │ 1.40571 │ 0.00053           │ ❌ INACTIVE │
# │ 2024-11-28 05:10:00 │ 1.35687 │ 0.00052           │ ❌ INACTIVE │
# │ 2024-11-28 05:15:00 │ 1.39038 │ 0.00053           │ ❌ INACTIVE │
# └─────────────────────┴─────────┴───────────────────┴─────────────┘
#                    time      open      high       low     close  tick_volume  \
# 0   2024-11-22 13:55:00  2693.738  2694.554  2692.679  2692.981          982
# 1   2024-11-22 14:00:00  2692.939  2693.753  2691.248  2691.985         1287
# ...

# %%
bot.display_indicators(df)
# Out:
# ╭─────────────────────────────────────────────── Indicator Values ────────────────────────────────────────────────╮
# │ ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓                                                                              │
# │ ┃ Indicator            ┃   Value ┃                                                                              │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩                                                                              │
# │ │ Supertrend Direction │ Bullish │                                                                              │
# │ │ Volatility           │  0.0005 │                                                                              │
# │ └──────────────────────┴─────────┘                                                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
df.columns
# Out:
# Index(['time', 'open', 'high', 'low', 'close', 'tick_volume', 'spread',
#        'real_volume', 'supertrend', 'supertrend_direction', 'supertrend_long',
#        'supertrend_short', 'atr', 'volatility_switch'],
#       dtype='object')

# %%
bot.get_trading_signal(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\miniconda3\envs\mt5\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 bot.get_trading_signal(df)
#
# File D:\CustomBot\trading_bot.py:298, in GoldTradingBot.get_trading_signal(self, df)
#     295 analysis = analyzer.analyze_price_action(df)
#     297 # Display analysis summary
# --> 298 self.display_analysis_summary(analysis)
#     300 # Trading conditions
#     301 conditions = {
#     302     'BUY': [
# ...

# %%
bot.volatility_threshold
# Out:
# 0.5

# %%
bot.monitor_live_prices()
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
bot.is_trading_time()
# Out:
# False

# %%
bot.run()
# Out:
# Checking MT5 Connection...
# Connected to: Exness-MT5Trial14
# Account: 190111246
# Current Bid: 2631.918
# Current Ask: 2632.03
# Bot started successfully!
# Trading hours: 11:00:00 - 02:30:00 IST
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
bot.calculate_supertrend(df)
# Out:
# Calculating Supertrend...
# Supertrend
# :      SUPERT_10_3.0  SUPERTd_10_3.0  SUPERTl_10_3.0  SUPERTs_10_3.0
# 0         0.000000               1             NaN             NaN
# 1              NaN               1             NaN             NaN
# 2              NaN               1             NaN             NaN
# 3              NaN               1             NaN             NaN
# 4              NaN               1             NaN             NaN
# ..             ...             ...             ...             ...
# 995    2629.394407               1     2629.394407             NaN
# 996    2629.394407               1     2629.394407             NaN
# 997    2629.394407               1     2629.394407             NaN
# 998    2629.394407               1     2629.394407             NaN
# 999    2629.394407               1     2629.394407             NaN
#
# [1000 rows x 4 columns]
# Calculated Supertrend using 1000 candles
# Supertrend Calculation Results:
# ...

# %%
mt5.account_info()

# %%
from datetime import datetime, time as datetime_time, timedelta

# %%
current_time = datetime.now()
current_time

# %%
start_time = current_time - timedelta(minutes=5 * 1000)
start_time

# %%
mt5.copy_rates_from("XAUUSD",mt5.TIMEFRAME_M5, start_time, current_time)

# %%
from trading_bot import GoldTradingBot
from rich.console import Console

# %%
console = Console()
bot = GoldTradingBot()

try:
    # Test connection
    if bot.check_connection():
        console.print("[green]Connection test successful![/green]")
        
        # Get a single live tick
        data = bot.get_live_data()
        if data is not None:
            console.print("\nLive Data Sample:")
            console.print(data)
    else:
        console.print("[red]Connection test failed![/red]")
        
except Exception as e:
    console.print(f"[red]Error: {str(e)}[/red]")
# Out:
# 🤖 Gold Trading Bot Initializing...
# ╭───────────────────────────────────────────────── Configuration ─────────────────────────────────────────────────╮
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓                                                                 │
# │ ┃ Parameter             ┃               Value ┃                                                                 │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩                                                                 │
# │ │ Symbol                │              XAUUSD │                                                                 │
# │ │ Timeframe             │                  M5 │                                                                 │
# │ │ Volatility Threshold  │                 0.5 │                                                                 │
# │ │ Max SL (pips)         │                  30 │                                                                 │
# ...

# %%
tick = mt5.symbol_info_tick("XAUUSD")

# %%
tick
# Out:
# Tick(time=1732770838, bid=2631.851, ask=2631.963, last=0.0, volume=0, time_msc=1732770838263, flags=6, volume_real=0.0)

# %%
bot.get_live_data()
# Out:
#                  time      open      high       low     close  tick_volume  \
# 0 2024-11-28 05:00:00  2631.255  2631.374  2630.115  2630.832          177
#
#    spread  real_volume  current_bid  current_ask
# 0     111            0     2630.832     2630.944

# %%
from datetime import datetime, time as datetime_time, timedelta

# %%
current_time = datetime.now()
start_time = current_time - timedelta(minutes=5 * 1000)

# %%
current_time
# Out:
# datetime.datetime(2024, 11, 28, 13, 7, 17, 124053)

# %%
start_time
# Out:
# datetime.datetime(2024, 11, 25, 1, 47, 17, 124053)

# %%
mt5.copy_rates_from_pos("XAUUSD", mt5.TIMEFRAME_M5, 0, 3000)
# Out:
# array([(1731493800, 2609.899, 2610.442, 2608.83 , 2609.803, 555, 112, 0),
#        (1731494100, 2609.792, 2609.796, 2608.068, 2608.602, 486, 112, 0),
#        (1731494400, 2608.626, 2608.755, 2606.974, 2607.144, 434, 111, 0),
#        ...,
#        (1732778700, 2637.819, 2638.87 , 2637.761, 2638.308, 381, 111, 0),
#        (1732779000, 2638.302, 2638.563, 2637.213, 2637.951, 431, 112, 0),
#        (1732779300, 2638.001, 2638.263, 2636.923, 2637.159, 280, 112, 0)],
#       dtype=[('time', '<i8'), ('open', '<f8'), ('high', '<f8'), ('low', '<f8'), ('close', '<f8'), ('tick_volume', '<u8'), ('spread', '<i4'), ('real_volume', '<u8')])

# %%
mt5.symbol_info_tick("XAUUSD").time
# Out:
# 1732770653

# %%
bot.get_rates_df()
# Out:
# Fetching market data...
# Rates
# : [(1732283400, 2691.637, 2695.118, 2691.067, 2693.697, 1094, 112, 0)
#  (1732283700, 2693.738, 2694.554, 2692.679, 2692.981,  982, 111, 0)
#  (1732284000, 2692.939, 2693.753, 2691.248, 2691.985, 1287, 111, 0)
#  (1732284300, 2691.981, 2692.254, 2689.527, 2691.687, 1271, 111, 0)
#  (1732284600, 2691.743, 2692.753, 2689.505, 2689.814, 1304, 112, 0)
#  (1732284900, 2689.787, 2691.451, 2689.104, 2691.222, 1173, 111, 0)
#  (1732285200, 2691.128, 2692.668, 2688.937, 2689.959, 1240, 112, 0)
#  (1732285500, 2689.924, 2690.055, 2685.897, 2687.724, 1382, 112, 0)
#  (1732285800, 2687.712, 2688.561, 2684.428, 2688.199, 2412, 111, 0)
#  (1732286100, 2688.227, 2691.519, 2686.952, 2691.268, 1724, 111, 0)
#  (1732286400, 2691.226, 2693.513, 2690.463, 2692.97 , 1424, 111, 0)
#  (1732286700, 2692.934, 2693.587, 2688.476, 2692.076, 3140, 111, 0)
#  (1732287000, 2692.1  , 2695.207, 2691.403, 2693.5  , 2290, 111, 0)
# ...

# %%
df.columns
# Out:
# Index(['time', 'open', 'high', 'low', 'close', 'tick_volume', 'spread',
#        'real_volume', 'atr', 'volatility_switch', 'supertrend',
#        'supertrend_direction', 'supertrend_long', 'supertrend_short'],
#       dtype='object')
